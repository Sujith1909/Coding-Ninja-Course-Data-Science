# %%
import pandas as pd
import operator
import matplotlib.pyplot as plt
df = pd.read_csv('IPL Ball-by-Ball 2008-2020.csv')

# %%
df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# ...

# %%
df_batsman = df['batsman']

# %%
df_is_six = df['batsman_runs']

# %%
df['batsman_runs'][7]
# Out:
# 1

# %%
dict1 = {}

# %%
for i in range(df.shape[0]):
    if(df['batsman_runs'][i] == 6):
        dict1[df['batsman'][i]]=dict1.get(df['batsman'][i],0)+1

# %%
dict1
# Out:
# {'BB McCullum': 261,
#  'RT Ponting': 5,
#  'P Kumar': 35,
#  'JH Kallis': 89,
#  'MEK Hussey': 105,
#  'SK Raina': 389,
#  'JDP Oram': 11,
#  'S Badrinath': 57,
#  'ML Hayden': 89,
#  'JR Hopes': 23,
#  'KC Sangakkara': 55,
#  'Yuvraj Singh': 299,
#  'SM Katich': 17,
#  'K Goel': 19,
#  'T Kohli': 3,
#  'RA Jadeja': 153,
#  'G Gambhir': 119,
#  'ST Jayasuriya': 79,
#  'AM Nayar': 41,
#  'SM Pollock': 17,
#  'RV Uthappa': 327,
#  'MV Boucher': 27,
#  'LRPL Taylor': 93,
#  'V Kohli': 405,
#  'AS Yadav': 5,
#  'A Symonds': 83,
#  'SB Bangar': 7,
#  'AC Gilchrist': 185,
#  'Mohammad Hafeez': 5,
#  'DJ Hussey': 121,
#  'SR Watson': 381,
#  'Kamran Akmal': 17,
#  'IK Pathan': 75,
#  'RG Sharma': 429,
#  'WPUJC Vaas': 7,
#  'V Sehwag': 213,
#  'MS Dhoni': 433,
#  'Harbhajan Singh': 85,
#  'MA Khote': 3,
#  'DJ Bravo': 123,
#  'SK Warne': 13,
#  'Shahid Afridi': 13,
#  'YK Pathan': 319,
#  'GC Smith': 19,
#  'M Kaif': 13,
#  'B Lee': 17,
#  'L Ronchi': 3,
#  'DPMD Jayawardene': 79,
# ...

# %%
ans = sorted(dict1.items(), key=lambda x: x[1],reverse = True)

# %%
ans
# Out:
# [('CH Gayle', 350),
#  ('AB de Villiers', 236),
#  ('MS Dhoni', 217),
#  ('RG Sharma', 215),
#  ('V Kohli', 203),
#  ('KA Pollard', 199),
#  ('DA Warner', 196),
#  ('SK Raina', 195),
#  ('SR Watson', 191),
#  ('RV Uthappa', 164),
#  ('YK Pathan', 160),
#  ('Yuvraj Singh', 150),
#  ('AT Rayudu', 133),
#  ('BB McCullum', 131),
#  ('AD Russell', 130),
#  ('DR Smith', 118),
#  ('SV Samson', 116),
#  ('S Dhawan', 110),
#  ('V Sehwag', 107),
#  ('KD Karthik', 106),
#  ('KL Rahul', 105),
#  ('RR Pant', 104),
#  ('MK Pandey', 94),
#  ('HH Pandya', 94),
#  ('AC Gilchrist', 93),
#  ('M Vijay', 92),
#  ('GJ Maxwell', 92),
#  ('DA Miller', 88),
#  ('SS Iyer', 84),
#  ('JP Duminy', 80),
#  ('NV Ojha', 80),
#  ('SE Marsh', 79),
#  ('JC Buttler', 78),
#  ('RA Jadeja', 77),
#  ('AM Rahane', 77),
#  ('Q de Kock', 77),
#  ('AJ Finch', 76),
#  ('F du Plessis', 74),
#  ('N Rana', 73),
#  ('MA Agarwal', 68),
#  ('WP Saha', 65),
#  ('Ishan Kishan', 65),
#  ('CA Lynn', 64),
#  ('DJ Bravo', 62),
# ...

# %%
for i in range(5):
    print(ans[i][0],ans[i][1])
# Out:
# CH Gayle 350
# AB de Villiers 236
# MS Dhoni 217
# RG Sharma 215
# V Kohli 203

# %% [markdown]
# # terrorismData.csv

# %%
import pandas as pd
import operator
import matplotlib.pyplot as plt
df = pd.read_csv('terrorismData.csv')

# %%
df
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
dict2 = {}

# %%
for i in range(df.shape[0]):
    dict2[df['Weapon_type'][i]]=dict2.get(df['Weapon_type'][i],0)+1

# %%
# Out:
# {'Unknown': 15158,
#  'Explosives': 92427,
#  'Incendiary': 11136,
#  'Firearms': 58525,
#  'Chemical': 322,
#  'Melee': 3656,
#  'Sabotage Equipment': 142,
#  'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)': 137,
#  'Fake Weapons': 34,
#  'Radiological': 15,
#  'Other': 115,
#  'Biological': 36}

# %%
ans = sorted(dict2.items(), key=lambda x: x[1],reverse = True)

# %%
ans
# Out:
# [('Explosives', 184853),
#  ('Firearms', 117049),
#  ('Unknown', 30315),
#  ('Incendiary', 22271),
#  ('Melee', 7311),
#  ('Chemical', 643),
#  ('Sabotage Equipment', 283),
#  ('Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)',
#   273),
#  ('Other', 229),
#  ('Biological', 71),
#  ('Fake Weapons', 67),
#  ('Radiological', 29)]

# %%
print(ans[0][0],ans[0][1])
print(ans[1][0],ans[1][1])
print(ans[3][0],ans[3][1])
print(ans[4][0],ans[4][1])
print(ans[5][0],ans[5][1])
# Out:
# Explosives 184853
# Firearms 117049
# Incendiary 22271
# Melee 7311
# Chemical 643

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('terrorismData.csv')
dict2 = {}
for i in range(df.shape[0]):
    dict2[df['Weapon_type'][i]]=dict2.get(df['Weapon_type'][i],0)+1
ans = sorted(dict2.items(), key=lambda x: x[1],reverse = True)
x = []
y = []
for i in range(6):
    if ans[i][0] == 'Unknown':
        continue
    print(ans[i][0],ans[i][1])
    x.append(ans[i][0])
    y.append(ans[i][1])
plt.bar(x,y,edgecolor='Black')
# Out:
# Explosives 92426
# Firearms 58524
# Incendiary 11135
# Melee 3655
# Chemical 321
# <BarContainer object of 5 artists>

# %%
x = []
y = []
for i in range(6):
    if ans[i][0] == 'Unknown':
        continue
    print(ans[i][0],ans[i][1])
    x.append(ans[i][0])
    y.append(ans[i][1])
plt.bar(x,y,edgecolor='Black')
# Out:
# Explosives 92426
# Firearms 58524
# Incendiary 11135
# Melee 3655
# Chemical 321
# <BarContainer object of 5 artists>

# %%
if ans[2][0] == 'Unknown':
    print('yes')
# Out:
# yes

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
import pandas as pd
import operator
import matplotlib.pyplot as plt
df = pd.read_csv('IPL Matches 2008-2020.csv')
df["city"]= df["city"].replace("Bangalore","Bengaluru")
dict1 = {}
for i in range(df.shape[0]):
    dict1[df['city'][i]]=dict1.get(df['city'][i],0)+1
ans = sorted(dict1.items(), key=lambda x: x[1],reverse = True)
x = []
y = []
for i in range(10):
    print(ans[i][0],ans[i][1])
    x.append(ans[i][0])
    y.append(ans[i][1])
plt.bar(x,y,edgecolor='Black')
# Out:
# Mumbai 101
# Bengaluru 80
# Kolkata 77
# Delhi 74
# Hyderabad 64
# Chennai 57
# Chandigarh 56
# Jaipur 47
# Pune 38
# Abu Dhabi 29
# <BarContainer object of 10 artists>

# %%
df["city"]= df["city"].replace("Bangalore","Bengaluru")

# %%
ans
# Out:
# [('Mumbai', 101),
#  ('Kolkata', 77),
#  ('Delhi', 74),
#  ('Bangalore', 65),
#  ('Hyderabad', 64),
#  ('Chennai', 57),
#  ('Chandigarh', 56),
#  ('Jaipur', 47),
#  ('Pune', 38),
#  ('Abu Dhabi', 29),
#  ('Dubai', 26),
#  ('Durban', 15),
#  ('Bengaluru', 15),
#  ('Visakhapatnam', 13),
#  (nan, 13),
#  ('Centurion', 12),
#  ('Ahmedabad', 12),
#  ('Sharjah', 12),
#  ('Rajkot', 10),
#  ('Dharamsala', 9),
#  ('Indore', 9),
#  ('Johannesburg', 8),
#  ('Cape Town', 7),
#  ('Port Elizabeth', 7),
#  ('Cuttack', 7),
#  ('Ranchi', 7),
#  ('Raipur', 6),
#  ('Kochi', 5),
#  ('Kanpur', 4),
#  ('East London', 3),
#  ('Kimberley', 3),
#  ('Nagpur', 3),
#  ('Bloemfontein', 2)]

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('terrorismData.csv')
dict2 = {}
for i in range(df.shape[0]):
    dict2[df['Weapon_type'][i]]=dict2.get(df['Weapon_type'][i],0)+1
ans = sorted(dict2.items(), key=lambda x: x[1],reverse = True)
x = []
y = []
for i in range(6):
    if ans[i][0] == 'Unknown':
        continue
    print(ans[i][0],ans[i][1])
    x.append(ans[i][0])
    y.append(ans[i][1])
plt.bar(x,y,edgecolor='Black')
# Out:
# Explosives 92426
# Firearms 58524
# Incendiary 11135
# Melee 3655
# Chemical 321
# <BarContainer object of 5 artists>
