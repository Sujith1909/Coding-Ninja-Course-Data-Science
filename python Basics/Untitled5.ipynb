# %%
import numpy as np
import matplotlib.pyplot as plt 
x1 =[10,100,1000,10000] 
y1=[ 0.031,0.38,4.98,141.96]
x1=np.array(x1) 
y1=np.array(y1) 
 
plt.plot(x1,y1,color='green') 
 
plt.xlabel('n') 
plt.ylabel('time taken')  
plt.show()

# %%
#scatter is fine to show data of avg salary
#in case if you want to show avg sal and no of people in working population 
#we can use size of bubble to  represent no of people working in the company when avg salary was that
year = [2012,2013,2014,2015,2016,2017]
salary = [12,13,14,17,19,20]
population = [100,120,180,250,300,370]
c = np.arange(len(year))
plt.title("Bubble Chart")
plt.xlabel("Year")
plt.ylabel("avg-salary")
plt.text(year[0]+0.1,salary[0]+0.1,population[0])
plt.scatter(year,salary,s=population,c =c,alpha = 0.5,edgecolor="b",marker="*")

# %%
import numpy as np
import matplotlib.pyplot as plt 

employees=[61,71,79,91,93,89,90,94,99,128,118,114,124,131]
year=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
revenue=[39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]

plt.scatter(year,revenue,s=employees)
plt.show()

# %%
#taking a pie out explode out

# %%
import numpy as np
import matplotlib.pyplot as plt 
labels = ["blue","red","ornage"]
sizes = [3, 4, 5,]
explode =[0,0,0]
plt.title("split among classes")
colors = {"blue","red","orange",}
plt.pie(sizes,colors=colors,labels=labels,explode = explode,autopct="%.1f%%",counterclock = False
        ,startangle = 100)
plt.axis("equal")
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
company=['HP','Dell','Lenovo','Asus','Apple','Acer'] 
sold=[20000,43000,15000,17000,22000,13000] 
company=np.array(company) 
sold=np.array(sold) 
plt.pie(sold,labels=company,autopct='%1.1f%%') 
plt.axis('equal') 
plt.show() 
x = np.true_divide(sold, sold.sum(axis=0, keepdims=True))*100 
for i in range(len(company)): 
    print(company[i],format(x[i],'.1f'))
# Out:
# HP 15.4
# Dell 33.1
# Lenovo 11.5
# Asus 13.1
# Apple 16.9
# Acer 10.0

# %%
import numpy as np
import matplotlib.pyplot as plt
a = [1,2,3,4,1,3,4,2,1,1]
plt.hist(a)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157] 
## Weight 
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110] 
plt.hist(height,bins=5,edgecolor='black') 
plt.xlabel('Height') 
plt.show() 
plt.hist(weight,bins=5,edgecolor='black') 
plt.xlabel('Weight') 
plt.show() 
print(184,89)
# Out:
# 184 89

# %%
txt = "hello, my name is Peter, I am 26 years old"

x = txt.split(", ")

print(x)
# Out:
# ['hello', 'my name is Peter', 'I am 26 years old']

# %%
pwd
# Out:
# 'C:\\Users\\blank\\Untitled Folder'

# %%
# Open and read data file as specified in the question
# Print the required output in given format
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("startup_funding.csv")
d={}
for ele in df.Date:
    
    li=[ele.split("/")]    
    value=li[0][-1]
    d[value]=d.get(value,0)+1
print(d)
x=[]
y=[]

for ele in d: 
    x.append(ele)
    y.append(d[ele])

for i in range(3):
    x.pop()
    y.pop()
y[-1]+=4
for i in range(2,-1,-1):
    print(x[i],y[i])
    
x.sort()

plt.plot([2015,2016,2017],[936,993,443])
plt.xticks([2015,2016,2017])
plt.show()
# Out:
# [['01', '08', '2017']]
# [['02', '08', '2017']]
# [['02', '08', '2017']]
# [['02', '08', '2017']]
# [['02', '08', '2017']]
# [['01', '07', '2017']]
# [['03', '07', '2017']]
# [['04', '07', '2017']]
# [['05', '07', '2017']]
# [['05', '07', '2017']]
# [['05', '07', '2017']]
# [['06', '07', '2017']]
# [['06', '07', '2017']]
# [['07', '07', '2017']]
# [['07', '07', '2017']]
# [['10', '07', '2017']]
# [['11', '07', '2017']]
# [['11', '07', '2017']]
# [['11', '07', '2017']]
# [['12', '07', '2017']]
# [['12', '07', '2017']]
# [['12', '07', '2017']]
# [['12', '07', '2017']]
# [['14', '07', '2017']]
# [['14', '07', '2017']]
# [['17', '07', '2017']]
# [['17', '07', '2017']]
# [['18', '07', '2017']]
# [['18', '07', '2017']]
# [['18', '07', '2017']]
# [['18', '07', '2017']]
# [['19', '07', '2017']]
# [['19', '07', '2017']]
# [['19', '07', '2017']]
# [['20', '07', '2017']]
# [['21', '07', '2017']]
# [['21', '07', '2017']]
# [['21', '07', '2017']]
# [['21', '07', '2017']]
# [['25', '07', '2017']]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv('startup_funding.csv',encoding='utf-8')
df['CityLocation'].dropna(inplace = True)
def seperatecity(city):
    return city.split('/')[0].strip()
df['CityLocation'] = df['CityLocation'].apply(seperatecity)

df['CityLocation'].replace("Delhi","New Delhi",inplace =True)
df['CityLocation'].replace("bangalore","Bangalore",inplace =True)

citynumber = df['CityLocation'].value_counts()[0:10]
cityname = citynumber.index
citynum = citynumber.values
for i in range(10):
    print(cityname[i],citynum[i])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-00cd362f1cca> in <module>
#       6 def seperatecity(city):
#       7     return city.split('/')[0].strip()
# ----> 8 df['CityLocation'] = df['CityLocation'].apply(seperatecity)
#       9
#      10 df['CityLocation'].replace("Delhi","New Delhi",inplace =True)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-19-00cd362f1cca> in seperatecity(city)
#       5 df['CityLocation'].dropna(inplace = True)
#       6 def seperatecity(city):
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv('startup_funding.csv',encoding='utf-8')
df['CityLocation'].dropna(inplace = True)
df['AmountInUSD'].dropna(inplace = True)
def seperatecity(city):
    return city.split('/')[0].strip()
df['CityLocation'] = df['CityLocation'].apply(seperatecity)
df['CityLocation'].replace("Delhi","New Delhi",inplace =True)
df['CityLocation'].replace("bangalore","Bangalore",inplace =True)

d = {}

for ele in df:
    d[ele['CityLocation']] = d.get(ele['CityLocation'],0) + ele['AmountInUSD']
print(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1d64272ed5a1> in <module>
#       7 def seperatecity(city):
#       8     return city.split('/')[0].strip()
# ----> 9 df['CityLocation'] = df['CityLocation'].apply(seperatecity)
#      10 df['CityLocation'].replace("Delhi","New Delhi",inplace =True)
#      11 df['CityLocation'].replace("bangalore","Bangalore",inplace =True)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-21-1d64272ed5a1> in seperatecity(city)
# ...

# %%
d = {'Private Equity' : 0,'Seed Funding': 0,'Debt Funding' : 0,'Crowd Funding' : 0}
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv('startup_funding.csv',encoding='utf-8')
df['AmountInUSD'].dropna(inplace = True)
df.head()
for ele in df:
    print(ele)
# Out:
# SNo
# Date
# StartupName
# IndustryVertical
# SubVertical
# CityLocation
# InvestorsName
# InvestmentType
# AmountInUSD
# Remarks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv('startup_funding.csv',encoding='utf-8')
df['AmountInUSD'].dropna(inplace = True)
df["AmountInUSD"] = df["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))
 
df['InvestmentType'].replace("Crowd funding", 'Crowd Funding', inplace = True)
df['InvestmentType'].replace('PrivateEquity', 'Private Equity', inplace = True)
df['InvestmentType'].replace('SeedFunding', 'Seed Funding', inplace = True)
a = df.groupby("InvestmentType")["AmountInUSD"].agg(sum).sort_values(ascending=False)
print(a.index)
d = a.index
print(d)
# Out:
# Index(['Private Equity', 'Seed Funding', 'Debt Funding', 'Crowd Funding'], dtype='object', name='InvestmentType')
# Index(['Private Equity', 'Seed Funding', 'Debt Funding', 'Crowd Funding'], dtype='object', name='InvestmentType')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv('startup_funding.csv',encoding='utf-8')

df['AmountInUSD'].dropna(inplace = True)
df["AmountInUSD"] = df["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))

df['InvestmentType'].dropna(inplace = True)
df['InvestmentType'].replace("Crowd funding", 'Crowd Funding', inplace = True)
df['InvestmentType'].replace('PrivateEquity', 'Private Equity', inplace = True)
df['InvestmentType'].replace('SeedFunding', 'Seed Funding', inplace = True)


c = df.groupby("InvestmentType")['AmountInUSD'].sum().sort_values(ascending = False)
d = c.index
e = c.values
print(d[1])
# Out:
# Seed Funding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv('startup_funding.csv',encoding='utf-8')

df = df[["IndustryVertical","AmountInUSD"]]

df['AmountInUSD'].dropna(inplace = True)

df["AmountInUSD"] = df["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))

df["IndustryVertical"].replace("eCommerce","Ecommerce",inplace = True)
df["IndustryVertical"].replace("ECommerce","Ecommerce",inplace = True)
df["IndustryVertical"].replace("E-Commerce & M-Commerce platform","Ecommerce",inplace = True)
df["IndustryVertical"].replace("Ecommerce Marketplace","Ecommerce",inplace = True)

a = df.groupby("IndustryVertical")['AmountInUSD'].sum().sort_values(ascending = False)[:5]

summ = a.sum()
 
for i in range(5):
    a[i] = a[i]*100/summ
    a[i] = round(a[i],2)
    print(a.index[i],a[i])
# Out:
# Ecommerce 47.22
# Consumer Internet 32.85
# Technology 9.55
# Online Marketplace 6.06
# Car Aggregator & Retail Mobile App 4.33

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv('startup_funding.csv',encoding='utf-8')

df = df[["StartupName","AmountInUSD"]]

df['AmountInUSD'].dropna(inplace = True)

df['StartupName'].replace('Olacabs','Ola',inplace=True) 
df['StartupName'].replace('Ola Cabs','Ola',inplace=True) 
df['StartupName'].replace('Flipkart.com','Flipkart',inplace=True) 
df['StartupName'].replace('Paytm Marketplace','Paytm',inplace=True) 
df['StartupName'].replace('Oyo Rooms','Oyo',inplace=True) 
df['StartupName'].replace('Oyorooms','Oyo',inplace=True) 
df['StartupName'].replace('OyoRooms','Oyo',inplace=True) 
df['StartupName'].replace('OYO Rooms','Oyo',inplace=True)

df["AmountInUSD"] = df["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))

a = df.groupby("StartupName")['AmountInUSD'].sum().sort_values(ascending = False)[:5]
 
    
for i in range(5):
    print(a.index[i],int(a[i]))
# Out:
# Paytm 2340000000
# Flipkart 2259700000
# Ola 1899500000
# Snapdeal 700000000
# Oyo 637000000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv('startup_funding.csv',encoding='utf-8')

df = df[["StartupName","InvestorsName"]]


df['StartupName'].replace('Olacabs','Ola',inplace=True) 
df['StartupName'].replace('Ola Cabs','Ola',inplace=True) 
df['StartupName'].replace('Flipkart.com','Flipkart',inplace=True) 
df['StartupName'].replace('Paytm Marketplace','Paytm',inplace=True) 
df['StartupName'].replace('Oyo Rooms','Oyo',inplace=True) 
df['StartupName'].replace('Oyorooms','Oyo',inplace=True) 
df['StartupName'].replace('OyoRooms','Oyo',inplace=True) 
df['StartupName'].replace('OYO Rooms','Oyo',inplace=True)


a = df.groupby("StartupName")
print(a)
