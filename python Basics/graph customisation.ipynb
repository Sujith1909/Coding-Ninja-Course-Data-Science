# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([0,1,2,3,4,5,6,7,9,10])
y=np.array([1,2,5,10,17,26,37,50,82,101])
plt.plot(x,y) 
plt.grid()
fig=plt.figure()b
plt.show()
print('60 to 70')
# Out:
# 60 to 70

# %%
import numpy as np 
import matplotlib.pyplot as plt 
x=np.arange(0,40,2) 
y=2**x 
plt.plot(x,y,'--',color='blue')
plt.grid() 
plt.show()
print(30)
# Out:
# 30

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,5,0.1)
y = x**3
z = x**2
plt.plot(x,y,color = "red",linewidth = 3,label = "X^3")
plt.ylabel("X^3")
plt.xlabel("sujith")
plt.title("matplotlib demo")
plt.plot(x,z,color = "b",label="X^2")
plt.legend()
plt.text(2,8,"Test",fontsize=2)
plt.axis([0,10,0,25])
plt.grid()
plt.show()
#title , lable for x , y axis
