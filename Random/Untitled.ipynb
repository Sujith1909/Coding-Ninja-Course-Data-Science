# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Compiled.csv',error_bad_lines=False)

# %%
df
# Out:
#      HDI Rank                    Country  1990  1995  2000  2005  2010  2011  \
# 0           1                     Norway  11.7  11.9  12.1  12.5  12.7  12.7
# 1           2                    Ireland   9.7  10.3  10.6  11.4    11  10.7
# 2           2                Switzerland  10.9  11.3  11.7  12.9  13.9  13.8
# 3           4     Hong Kong, China (SAR)   9.4   9.4   9.3  11.3    12  12.2
# 4           4                    Iceland   8.4   8.8   9.3   9.9  10.4  10.8
# ..        ...                        ...   ...   ...   ...   ...   ...   ...
# 170       185                    Burundi   2.1   2.2   2.5   2.9   3.1   3.3
# 171       185                South Sudan    ..    ..    ..    ..   5.3   5.3
# 172       187                       Chad    ..    ..    ..   2.3   2.9     3
# 173       188   Central African Republic   3.1   3.7   4.2   4.7   5.7   5.7
# 174       189                      Niger   1.1   1.4   1.7   1.9     2   2.1
#
# ...

# %%
for ind in df.index:
     print(df['HDI Rankind'], df['Country'][ind])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HDI Rankind'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-371d14934552> in <module>
#       1 for ind in df.index:
# ...
